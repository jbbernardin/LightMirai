# %%
# !pip install -r requirements.txt
# Out:
# Collecting torch (from -r requirements.txt (line 1))
#   Using cached torch-2.5.1-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting torchvision (from -r requirements.txt (line 2))
#   Using cached torchvision-0.20.1-cp310-cp310-win_amd64.whl.metadata (6.2 kB)
# Collecting scikit-learn (from -r requirements.txt (line 3))
#   Using cached scikit_learn-1.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting scipy (from -r requirements.txt (line 4))
#   Using cached scipy-1.14.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting numpy (from -r requirements.txt (line 5))
#   Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting Pillow (from -r requirements.txt (line 6))
#   Using cached pillow-11.0.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting tqdm (from -r requirements.txt (line 7))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting mock (from -r requirements.txt (line 8))
#   Using cached mock-5.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting scikit-image (from -r requirements.txt (line 9))
#   Using cached scikit_image-0.24.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting imageio (from -r requirements.txt (line 10))
#   Using cached imageio-2.36.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting gitpython (from -r requirements.txt (line 11))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting lifelines (from -r requirements.txt (line 12))
#   Using cached lifelines-0.30.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: ipykernel in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from -r requirements.txt (line 13)) (6.29.5)
# Collecting filelock (from torch->-r requirements.txt (line 1))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from torch->-r requirements.txt (line 1)) (4.12.2)
# Collecting networkx (from torch->-r requirements.txt (line 1))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->-r requirements.txt (line 1))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch->-r requirements.txt (line 1))
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch->-r requirements.txt (line 1))
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->-r requirements.txt (line 1))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 3))
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r requirements.txt (line 3))
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from tqdm->-r requirements.txt (line 7)) (0.4.6)
# Collecting tifffile>=2022.8.12 (from scikit-image->-r requirements.txt (line 9))
#   Using cached tifffile-2024.9.20-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from scikit-image->-r requirements.txt (line 9)) (24.2)
# Collecting lazy-loader>=0.4 (from scikit-image->-r requirements.txt (line 9))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython->-r requirements.txt (line 11))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting pandas>=2.1 (from lifelines->-r requirements.txt (line 12))
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib>=3.0 (from lifelines->-r requirements.txt (line 12))
#   Using cached matplotlib-3.9.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting autograd>=1.5 (from lifelines->-r requirements.txt (line 12))
#   Using cached autograd-1.7.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting autograd-gamma>=0.3 (from lifelines->-r requirements.txt (line 12))
#   Using cached autograd_gamma-0.5.0-py3-none-any.whl
# Collecting formulaic>=0.2.2 (from lifelines->-r requirements.txt (line 12))
#   Using cached formulaic-1.0.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (1.8.9)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipykernel->-r requirements.txt (line 13)) (5.14.3)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.2.2->lifelines->-r requirements.txt (line 12))
#   Using cached interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting wrapt>=1.0 (from formulaic>=0.2.2->lifelines->-r requirements.txt (line 12))
#   Using cached wrapt-1.17.0-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 11))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: decorator in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 13)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 13)) (307)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->lifelines->-r requirements.txt (line 12))
#   Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->lifelines->-r requirements.txt (line 12))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->lifelines->-r requirements.txt (line 12))
#   Downloading fonttools-4.55.0-cp310-cp310-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->lifelines->-r requirements.txt (line 12))
#   Using cached kiwisolver-1.4.7-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.0->lifelines->-r requirements.txt (line 12))
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting pytz>=2020.1 (from pandas>=2.1->lifelines->-r requirements.txt (line 12))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.1->lifelines->-r requirements.txt (line 12))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r requirements.txt (line 1))
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jbber\anaconda3\envs\light_mirai\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.3)
# Using cached torch-2.5.1-cp310-cp310-win_amd64.whl (203.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached torchvision-0.20.1-cp310-cp310-win_amd64.whl (1.6 MB)
# Using cached scikit_learn-1.5.2-cp310-cp310-win_amd64.whl (11.0 MB)
# Using cached scipy-1.14.1-cp310-cp310-win_amd64.whl (44.8 MB)
# Downloading numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.9 MB 16.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/12.9 MB 16.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 14.7 MB/s eta 0:00:00
# Using cached pillow-11.0.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached mock-5.1.0-py3-none-any.whl (30 kB)
# Using cached scikit_image-0.24.0-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached imageio-2.36.0-py3-none-any.whl (315 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached lifelines-0.30.0-py3-none-any.whl (349 kB)
# Using cached autograd-1.7.0-py3-none-any.whl (52 kB)
# Using cached formulaic-1.0.2-py3-none-any.whl (94 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached matplotlib-3.9.2-cp310-cp310-win_amd64.whl (7.8 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached tifffile-2024.9.20-py3-none-any.whl (228 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading contourpy-1.3.1-cp310-cp310-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.0-cp310-cp310-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 15.6 MB/s eta 0:00:00
# Using cached interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Using cached kiwisolver-1.4.7-cp310-cp310-win_amd64.whl (55 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached wrapt-1.17.0-cp310-cp310-win_amd64.whl (38 kB)
# Installing collected packages: pytz, mpmath, wrapt, tzdata, tqdm, threadpoolctl, sympy, smmap, pyparsing, Pillow, numpy, networkx, mock, MarkupSafe, lazy-loader, kiwisolver, joblib, interface-meta, fsspec, fonttools, filelock, cycler, tifffile, scipy, pandas, jinja2, imageio, gitdb, contourpy, autograd, torch, scikit-learn, scikit-image, matplotlib, gitpython, formulaic, autograd-gamma, torchvision, lifelines
# Successfully installed MarkupSafe-3.0.2 Pillow-11.0.0 autograd-1.7.0 autograd-gamma-0.5.0 contourpy-1.3.1 cycler-0.12.1 filelock-3.16.1 fonttools-4.55.0 formulaic-1.0.2 fsspec-2024.10.0 gitdb-4.0.11 gitpython-3.1.43 imageio-2.36.0 interface-meta-1.3.0 jinja2-3.1.4 joblib-1.4.2 kiwisolver-1.4.7 lazy-loader-0.4 lifelines-0.30.0 matplotlib-3.9.2 mock-5.1.0 mpmath-1.3.0 networkx-3.4.2 numpy-2.1.3 pandas-2.2.3 pyparsing-3.2.0 pytz-2024.2 scikit-image-0.24.0 scikit-learn-1.5.2 scipy-1.14.1 smmap-5.0.1 sympy-1.13.1 threadpoolctl-3.5.0 tifffile-2024.9.20 torch-2.5.1 torchvision-0.20.1 tqdm-4.67.1 tzdata-2024.2 wrapt-1.17.0

# %%
import pandas as pd
import os
import glob
from PIL import Image

# %% [markdown]
# # Data Preprocessing

# %%
# ONLY DO THIS ONCE. It took 78 minutes on my machine


input_directory = 'raw_data/jpeg/'
output_directory = 'raw_data/png16/'

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

for foldername, subfolders, filenames in os.walk(input_directory):
    for filename in filenames:
        if filename.endswith('.jpg') or filename.endswith('.jpeg'):

            img_path = os.path.join(foldername, filename)
            img = Image.open(img_path)
            
            relative_path = os.path.relpath(foldername, input_directory)
            output_folder = os.path.join(output_directory, relative_path)
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
            
            png16_filename = os.path.splitext(filename)[0] + '.png'
            png16_save_path = os.path.join(output_folder, png16_filename)
            img.save(png16_save_path, format='PNG', bits=16)

print("Conversion completed.")
# Out:
# Conversion completed.

# %%
img_base_path = "C:/Users/jbber/.vscode/LightMirai/raw_data/png16/" 
csv_base_path = "C:/Users/jbber/.vscode/LightMirai/raw_data/csv/" 

def process_data(filepath, output_path=None):

    data = pd.read_csv(filepath)
    data[['file_path', 'mask_path']] = data.apply(map_image_paths, axis=1)

    processed_data = pd.DataFrame({
        'patient_id': data['patient_id'],
        'exam_id': data.groupby('patient_id').cumcount(),
        'laterality': data['left or right breast'].astype(str).str.strip().str[0].str.upper(),
        'view': data['image view'], 
        'file_path': data['file_path'], 
        'mask_path': data['mask_path'],
    })

    if output_path is not None:
        processed_data.to_csv(output_path, index=False)
        print(f"Processed data saved to {output_path}")

    return processed_data

def map_image_paths(row):

    folder_name = os.path.basename(os.path.dirname(row['ROI mask file path']))
    folder_path = os.path.join(img_base_path, folder_name)
    
    if not os.path.exists(folder_path):
        print(f"Warning: Folder {folder_path} does not exist.")
        return pd.Series([None, None])
        
    mammogram_file = next(
        (f for f in glob.glob(os.path.join(folder_path, "1-*.png")) if len(os.path.basename(f).split('-')[-1]) == 7),
        None
    )
    mask_file = next(
        (f for f in glob.glob(os.path.join(folder_path, "2-*.png")) if len(os.path.basename(f).split('-')[-1]) == 7),
        None
    )
    
    if not mammogram_file:
        print(f"Warning: No mammogram file (1-*.png) found in {folder_path}.")
    if not mask_file:
        print(f"Warning: No mask file (2-*.png) found in {folder_path}.")
    
    return pd.Series([mammogram_file, mask_file])

def merge_data(dataframe_1, dataframe_2):
    if list(dataframe_1.columns) != list(dataframe_2.columns):
        raise ValueError("DataFrames have different columns and cannot be merged.")

    merged_dataframe = pd.concat([dataframe_1, dataframe_2], ignore_index=True)
    merged_dataframe.drop_duplicates(inplace=True)

    return merged_dataframe

calc_train_data = process_data(csv_base_path + "calc_case_description_train_set.csv")
calc_test_data = process_data(csv_base_path + "calc_case_description_test_set.csv")

mass_train_data = process_data(csv_base_path + "mass_case_description_train_set.csv")
mass_test_data = process_data(csv_base_path + "mass_case_description_test_set.csv")

train_data = merge_data(calc_train_data, mass_train_data)
test_data = merge_data(calc_test_data, mass_test_data)

train_data.to_csv("clean_data/train.csv")
test_data.to_csv("clean_data/test.csv")
# Out:
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.323173986211744534717152497940376023803.
# Warning: Folder C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.348822970413183698610798947061334416506 does not exist.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.203970065112706924324370021454096282600.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.213479805111756800235140829670343680695.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.167721256311930226218015781691859713018.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.312064575313543515220300745352630857321.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.278022131711751825320356179721710838376.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.62477624313950073629115651880107415441.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.11522965912391185905725226742050551997.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.146913909913541364323336672252941023907.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.106997984011096179332011485603799417912.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.150257282810473809225363132553623499374.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.395347017912616091013118601414152815246.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.7604728113021161016894457634011223447.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.33581058512698762002009391831905636976.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.244149282511184643506445666910676855808.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.310343042212571725139090395242913592142.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.282589057612957708106733336421961502025.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.281961437213188582700339444571620094246.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.287268392410728423220392208833183947061.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.390567474013224873401992073280403336260.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.370920373213998366810048183042514597276.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.236234414511610825527153660610660728538.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.152651387611683891810601424742731153937.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.132473816912356880934882917483772800157.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.311141337311026124238270647592124957147.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.29874535413588066822824838883550729379.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.151809261912849437430594088173996846400.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.419105484612765353125653224301479837209.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.25675010911265175932026938004227312743.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.63569235411594409607214585841671276939.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.425162930912384986839410113794133819497.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.104547588711613761739645710270165941887.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.308183410113218061709558091841282060108.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.291970834411466767515548699420271393213.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.354393322011557367835928690122016618367.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.320866693113864447514884110163742534443.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.936360511151457135028361121849377304.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.359055594811353162117419393722126293297.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.372474890613185447528754021491583664783.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.141678145812357525119018436363859433081.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.317162531011841095240854206924099270129.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.159789089511044436630882300743522788770.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.58165654512334946416852640461650981142.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.116402188313857340041067573043844694842.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.225996552111851845434924545761968430242.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.172312913811899954603939792771735246466.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.127049286110901700226076706703952274283.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.366476594211196854917146694673979411915.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.350981553411772244426195844303320272166.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.397878670112258535539834295382406058317.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.191581431611130104818482996532202750166.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.23469712812014256806861933360722981844.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.218276781510398310040036064503120593339.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.115756551511607539711774227830474877280.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.387602814412915980933284786482185012652.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.202401703511057514802783952781477319590.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.415462595712128360934038539982805675099.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.290132331713952740012813940541363842293.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.398497021411248339900060809392361766695.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.168149569810088826820706454160568691402.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.153292899210265727229279763681299112046.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.142313024210626909616380200202083720554.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.139721753411251440715275690821492037186.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.100905990410891350726987703140883813087.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.266072811911023523927841675793019037832.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.110616775412403510003031638183621897337.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.368434953512686740334071092910393175106.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.90562377111576588437240836140991805023.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.219155182110475447623755959603632750640.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.200982276111200652312384078352354358026.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.414296620410983523236535970942544193675.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.189968356610649865535673586433840970668.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.250336634911097557638443680202588416494.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.203399722911412312801720083332539942756.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.19665754512295252425426031390768754621.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.214246281012674606311879883570054309779.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.8948994112564847239528500832754107853.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.255633232213862488229697596482706646126.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.416516221012584777431663420301643743534.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.69531019711204690717138379752809061274.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.159046574612998673315083542350464494818.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.47509236813928721433893050102757283168.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.291456982912877433901632375470543780956.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.343948967311982029004989313710355633688.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.371813759313271994601228594001917046161.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.34218151912946268510958967670853052175.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.35571788212802531401890896782882200908.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.89237466312426240700912480394071433919.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.94662217113501054508174890510669825986.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.303546712613051145839963503541170840323.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.387325662211652062642152657100487063460.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.237405159212695555542386297803769689402.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.203989029910964209440425982812598330086.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.88091748413596024615343003341621545741.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.71333513012885558329531613884249028215.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.206133830412739740219136620982493384137.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.77795177210720655324735986231176035759.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.34719084810338030929028689201743802900.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.213373259211561590636126913501301096523.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.417648191012923677524976239580596100929.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.168513812311307055427394175041471803029.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.84252652613949378218158585893387800265.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.62743301211495345835434566670294393832.
# Warning: No mask file (2-*.png) found in C:/Users/jbber/.vscode/LightMirai/raw_data/png16/1.3.6.1.4.1.9590.100.1.2.250048723412722873040250881911272043627.

# %%
print("Training Set:\n")

print(train_data.head())
print(train_data.tail())
print(train_data.info())
print(train_data.describe(include='all'))
print(train_data.columns)
print(train_data.shape)
print(train_data.dtypes)
print(train_data.isnull().sum())
print(f"Number of duplicate rows: {len(train_data[train_data.duplicated()])}")

print("Testing Set:\n")

print(test_data.head())
print(test_data.tail())
print(test_data.info())
print(test_data.describe(include='all'))
print(test_data.columns)
print(test_data.shape)
print(test_data.dtypes)
print(test_data.isnull().sum())
print(f"Number of duplicate rows: {len(test_data[test_data.duplicated()])}")
# Out:
# Training Set:
#
#   patient_id  exam_id laterality view  \
# 0    P_00005        0          R   CC
# 1    P_00005        1          R  MLO
# 2    P_00007        0          L   CC
# 3    P_00007        1          L  MLO
# 4    P_00008        0          L   CC
#
#                                            file_path  \
# 0  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 1  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 2  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 3  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 4  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
#
#                                            mask_path
# 0  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 1  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 2  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 3  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 4  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
#      patient_id  exam_id laterality view  \
# 2859    P_02033        1          R  MLO
# 2860    P_02079        0          R   CC
# 2861    P_02079        1          R  MLO
# 2862    P_02092        0          L   CC
# 2863    P_02092        1          L  MLO
#
#                                               file_path mask_path
# 2859  C:/Users/jbber/.vscode/LightMirai/raw_data/png...      None
# 2860  C:/Users/jbber/.vscode/LightMirai/raw_data/png...      None
# 2861  C:/Users/jbber/.vscode/LightMirai/raw_data/png...      None
# 2862  C:/Users/jbber/.vscode/LightMirai/raw_data/png...      None
# 2863  C:/Users/jbber/.vscode/LightMirai/raw_data/png...      None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   patient_id  2864 non-null   object
#  1   exam_id     2864 non-null   int64
#  2   laterality  2864 non-null   object
#  3   view        2864 non-null   object
#  4   file_path   2863 non-null   object
#  5   mask_path   2770 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 134.4+ KB
# None
#        patient_id      exam_id laterality  view  \
# count        2864  2864.000000       2864  2864
# unique       1248          NaN          2     2
# top       P_01437          NaN          L   MLO
# freq           24          NaN       1449  1518
# mean          NaN     1.327863        NaN   NaN
# std           NaN     2.508605        NaN   NaN
# min           NaN     0.000000        NaN   NaN
# 25%           NaN     0.000000        NaN   NaN
# 50%           NaN     1.000000        NaN   NaN
# 75%           NaN     1.000000        NaN   NaN
# max           NaN    23.000000        NaN   NaN
#
#                                                 file_path  \
# count                                                2863
# unique                                               2863
# top     C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 mask_path
# count                                                2770
# unique                                               2770
# top     C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# Index(['patient_id', 'exam_id', 'laterality', 'view', 'file_path',
#        'mask_path'],
#       dtype='object')
# (2864, 6)
# patient_id    object
# exam_id        int64
# laterality    object
# view          object
# file_path     object
# mask_path     object
# dtype: object
# patient_id     0
# exam_id        0
# laterality     0
# view           0
# file_path      1
# mask_path     94
# dtype: int64
# Number of duplicate rows: 0
# Testing Set:
#
#   patient_id  exam_id laterality view  \
# 0    P_00038        0          L   CC
# 1    P_00038        1          L  MLO
# 2    P_00038        2          R   CC
# 3    P_00038        3          R   CC
# 4    P_00038        4          R  MLO
#
#                                            file_path  \
# 0  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 1  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 2  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 3  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 4  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
#
#                                            mask_path
# 0  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 1  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 2  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 3  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 4  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
#     patient_id  exam_id laterality view  \
# 699    P_01825        1          R  MLO
# 700    P_01833        0          R  MLO
# 701    P_01865        0          L  MLO
# 702    P_01912        0          R   CC
# 703    P_01912        1          R  MLO
#
#                                              file_path  \
# 699  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 700  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 701  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 702  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 703  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
#
#                                              mask_path
# 699  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 700  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 701  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 702  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# 703  C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   patient_id  704 non-null    object
#  1   exam_id     704 non-null    int64
#  2   laterality  704 non-null    object
#  3   view        704 non-null    object
#  4   file_path   704 non-null    object
#  5   mask_path   693 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 33.1+ KB
# None
#        patient_id     exam_id laterality view  \
# count         704  704.000000        704  704
# unique        349         NaN          2    2
# top       P_00140         NaN          L  MLO
# freq            8         NaN        370  378
# mean          NaN    0.768466        NaN  NaN
# std           NaN    1.100407        NaN  NaN
# min           NaN    0.000000        NaN  NaN
# 25%           NaN    0.000000        NaN  NaN
# 50%           NaN    0.500000        NaN  NaN
# 75%           NaN    1.000000        NaN  NaN
# max           NaN    7.000000        NaN  NaN
#
#                                                 file_path  \
# count                                                 704
# unique                                                704
# top     C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 mask_path
# count                                                 693
# unique                                                693
# top     C:/Users/jbber/.vscode/LightMirai/raw_data/png...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# Index(['patient_id', 'exam_id', 'laterality', 'view', 'file_path',
#        'mask_path'],
#       dtype='object')
# (704, 6)
# patient_id    object
# exam_id        int64
# laterality    object
# view          object
# file_path     object
# mask_path     object
# dtype: object
# patient_id     0
# exam_id        0
# laterality     0
# view           0
# file_path      0
# mask_path     11
# dtype: int64
# Number of duplicate rows: 0
